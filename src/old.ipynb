# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
interactiondata = pd.read_csv('../data/interactiondata.csv')
userdata = pd.read_csv('../data/userdata.csv')

df = pd.merge(interactiondata, userdata, on='userid')
df.head()

df['join_datetime'] = pd.to_datetime(df['join_datetime'])

df['join_date'] = df['join_datetime'].dt.date

df['max_bill']

# %%
df["orders_num"] = np.zeros(df.shape[0])

orders = pd.read_csv('../data/orderdata.csv')
for i in range(orders.shape[0]):
    user_id = orders['userid'][i]
    df.loc[df['userid'] == user_id, 'orders_num'] += 1
    
df.head(5)
# Out:
#                                  userid  complain_count last_order_dt  \
# 0  fa432faf-93f6-4dbf-ae14-8a8b681a106f               0    2024-06-22
# 1  3146a104-ede9-4cbb-8869-b65cf60a35d0               0    2024-05-17
# 2  191455cb-b4cc-4ef4-abf6-056349caf299               2    2024-05-27
# 3  e0037cb7-8e9a-4adf-b03a-ea8d9bcb67e9               0    2024-06-03
# 4  00c8adb8-4694-4137-a352-404bd16cd299               0    2024-07-02
#
#    discount_purchases_count_avg  catalogue_purchases_count_avg  \
# 0                             2                              0
# 1                             2                              0
# 2                             2                              2
# 3                             5                              0
# 4                             0                              0
#
#    store_purchases_count_avg  website_purchases_count_avg  \
# 0                          4                            3
# ...

# %%
# Добавление новых столбцов в df_corr для расчета корреляции
df_corr = pd.DataFrame({
    'income': df['income'],
    'discount_purchases_count_avg': df['discount_purchases_count_avg'],
    'catalogue_purchases_count_avg': df['catalogue_purchases_count_avg'],
    'store_purchases_count_avg': df['store_purchases_count_avg'],
    'website_purchases_count_avg': df['website_purchases_count_avg'],
    'website_visit_count_avg': df['website_visit_count_avg'],
    'mobile_purchases_count_avg': df['mobile_purchases_count_avg'],
    'mobile_visit_count_avg': df['mobile_visit_count_avg']
})

correlation_matrix
# Out:
#                                  income  discount_purchases_count_avg  \
# income                         1.000000                      0.085569
# discount_purchases_count_avg   0.085569                      1.000000
# catalogue_purchases_count_avg  0.642316                      0.073234
# store_purchases_count_avg      0.709605                      0.004353
# website_purchases_count_avg    0.504327                      0.071357
# website_visit_count_avg        0.004781                      0.573017
# mobile_purchases_count_avg     0.290571                      0.560767
# mobile_visit_count_avg         0.066671                      0.652266
#
#                                catalogue_purchases_count_avg  \
# income                                              0.642316
# discount_purchases_count_avg                        0.073234
# catalogue_purchases_count_avg                       1.000000
# store_purchases_count_avg                           0.616262
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.show()

# %%
columns = df_corr.columns

for i in range(len(columns)):
    for j in range(len(columns)):
        if i != j:
            X = df_corr[columns[i]].values.reshape(-1, 1)
            Y = df_corr[columns[j]]

            model = LinearRegression()
            model.fit(X, Y)

            score = model.score(X, Y)  # R^2

            print(f'R^2 score for {columns[i]} vs {columns[j]}: {score:.4f}')
# Out:
# R^2 score for income vs discount_purchases_count_avg: 0.0073
# R^2 score for income vs catalogue_purchases_count_avg: 0.4126
# R^2 score for income vs store_purchases_count_avg: 0.5035
# R^2 score for income vs website_purchases_count_avg: 0.2543
# R^2 score for income vs website_visit_count_avg: 0.0000
# R^2 score for income vs mobile_purchases_count_avg: 0.0844
# R^2 score for income vs mobile_visit_count_avg: 0.0044
# R^2 score for discount_purchases_count_avg vs income: 0.0073
# R^2 score for discount_purchases_count_avg vs catalogue_purchases_count_avg: 0.0054
# R^2 score for discount_purchases_count_avg vs store_purchases_count_avg: 0.0000
# R^2 score for discount_purchases_count_avg vs website_purchases_count_avg: 0.0051
# R^2 score for discount_purchases_count_avg vs website_visit_count_avg: 0.3283
# R^2 score for discount_purchases_count_avg vs mobile_purchases_count_avg: 0.3145
# R^2 score for discount_purchases_count_avg vs mobile_visit_count_avg: 0.4255
# ...

# %%
data_for_plot = df.groupby('last_order_dt').size()

print(data_for_plot)

plt.figure(figsize=(10, 6))
data_for_plot.plot(kind='bar')
plt.xlabel('Дата')
plt.ylabel('Количество пользователей')
plt.title('Количество пользователей, для которых день стал последней покупкой')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

'''# Найдем дату после которой был скачек в 3+ раз
for i in range(1, len(data_for_plot)):
    if data_for_plot[i] > 3 * data_for_plot[i-1]:
        print(data_for_plot.index[i])
        break'''

# 20 июня
# Out:
# last_order_dt
# 2024-05-11     29
# 2024-05-12     25
# 2024-05-13     27
# 2024-05-14     30
# 2024-05-15     30
# 2024-05-16     26
# 2024-05-17     35
# 2024-05-18     35
# 2024-05-19     28
# 2024-05-20     29
# 2024-05-21     26
# 2024-05-22     28
# 2024-05-23     24
# 2024-05-24     18
# 2024-05-25     22
# 2024-05-26     27
# 2024-05-27     31
# 2024-05-28     24
# 2024-05-29     29
# 2024-05-30     22
# 2024-05-31     29
# 2024-06-01     28
# 2024-06-02     33
# 2024-06-03     28
# 2024-06-04     23
# 2024-06-05     33
# 2024-06-06     35
# 2024-06-07     32
# 2024-06-08     28
# 2024-06-09     34
# 2024-06-10     30
# 2024-06-11     28
# 2024-06-12     28
# 2024-06-13     24
# 2024-06-14     27
# 2024-06-15     33
# 2024-06-16     37
# 2024-06-17     21
# 2024-06-18     36
# 2024-06-19     28
# 2024-06-20     28
# 2024-06-21     27
# 2024-06-22     25
# 2024-06-23     26
# 2024-06-24     30
# 2024-06-25    149
# 2024-06-26    156
# 2024-06-27    155
# 2024-06-28    144
# ...

# %%
df['join_date'] = pd.to_datetime(df['join_date'])
data_for_plot = df.groupby(pd.Grouper(key='join_date', freq='W')).size()

print(data_for_plot)

plt.figure(figsize=(10, 6))
data_for_plot.plot(kind='bar')
plt.xlabel('Неделя регистрации')
plt.ylabel('Количество пользователей')
plt.title('Количество пользователей по неделям регистрации')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# join_date
# 2022-05-01    13
# 2022-05-08    18
# 2022-05-15    18
# 2022-05-22    29
# 2022-05-29    25
#               ..
# 2024-05-12    37
# 2024-05-19    34
# 2024-05-26    33
# 2024-06-02    29
# 2024-06-09    17
# Freq: W-SUN, Length: 111, dtype: int64

# %%
# Для каждого пользвоателя найдем частоту покупок
df['last_order_dt'] = pd.to_datetime(df['last_order_dt'])
df['join_datetime'] = pd.to_datetime(df['join_datetime'])

df['frequency'] = round((df['last_order_dt'] - df['join_datetime']).dt.days / df['orders_num'])
df.head(20)
# Out:
#                                   userid  complain_count last_order_dt  \
# 0   fa432faf-93f6-4dbf-ae14-8a8b681a106f               0    2024-06-22
# 1   3146a104-ede9-4cbb-8869-b65cf60a35d0               0    2024-05-17
# 2   191455cb-b4cc-4ef4-abf6-056349caf299               2    2024-05-27
# 3   e0037cb7-8e9a-4adf-b03a-ea8d9bcb67e9               0    2024-06-03
# 4   00c8adb8-4694-4137-a352-404bd16cd299               0    2024-07-02
# 5   38c84b62-8717-4918-bb1a-53957d14ca81               0    2024-05-25
# 6   02448415-4639-4db9-a5f2-796e85fafc8e               2    2024-06-27
# 7   19742c01-82da-4fe9-8770-131707627390               0    2024-05-17
# 8   a1d274f0-03b7-4b39-92a5-3dcbca946a0b               0    2024-05-17
# 9   fbf550fd-58e4-44d4-9c6c-214a18a64349               0    2024-06-04
# 10  be576e3b-7412-49fe-bf2c-da7223a33606               0    2024-07-05
# 11  5790a1a2-6a0c-420a-9887-fcccea59e205               0    2024-06-02
# ...

# %%
def exponential_smoothing(data, alpha=0.3):
    smoothed_data = [data[0]]  # Initialize with the first data point
    for i in range(1, len(data)):
        smoothed_value = alpha * data[i] + (1 - alpha) * smoothed_data[i-1]
        smoothed_data.append(smoothed_value)
    return pd.Series(smoothed_data)

df = df[df['frequency'] >= 0]
frequency_counts = df.groupby('frequency').size()
# Plot
plt.figure(figsize=(10, 6))
frequency_counts.plot(kind='bar', color='b')

plt.title('Count of People by Frequency')
plt.xlabel('Frequency')
plt.ylabel('Count of People')
plt.grid(True)
plt.xticks(rotation=45)

plt.show()

# %%
from scipy.stats import shapiro

# Assuming frequency_counts is already defined as shown in your code
stat, p = shapiro(frequency_counts)
print('Statistics=%.3f, p=%.3f' % (stat, p))

# Interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.988, p=0.413
# Sample looks Gaussian (fail to reject H0)

# %%
# Вытащим данные по маркетинговым кампаниям у тех людей, что ушли после 25
after_people = df[df['last_order_dt'] >= pd.to_datetime("2024-06-25")]
after_people_marketing = pd.DataFrame({
    'marketing_company_outcome_1': after_people['marketing_company_outcome_1'],
    'marketing_company_outcome_2': after_people['marketing_company_outcome_2'],
    'marketing_company_outcome_3': after_people['marketing_company_outcome_3'],
    'marketing_company_outcome_4': after_people['marketing_company_outcome_4'],
    'marketing_company_outcome_5': after_people['marketing_company_outcome_5']
})

website_orders = after_people['website_purchases_count_avg']
mobile_orders = after_people['mobile_purchases_count_avg']
catalogue_orders = after_people['catalogue_purchases_count_avg']
discount_orders = after_people['discount_purchases_count_avg']

print("Mean website orders:", website_orders.mean())
print("Mean mobile orders:", mobile_orders.mean())
print("Mean catalogue orders:", catalogue_orders.mean())
print("Mean discount orders:", discount_orders.mean())

website_conversion = website_orders.mean() / after_people['website_visit_count_avg'].mean()
mobile_conversion = mobile_orders.mean() / after_people['mobile_visit_count_avg'].mean()

print("Website conversion:", website_conversion)
print("Mobile conversion:", mobile_conversion)



before_people_marketing

# Для каждого столбца найдем конверсию маркетинга
for i in range(1, 6):
    print(f"Mean {i}:", after_people_marketing[f'marketing_company_outcome_{i}'].mean())
# Out:
# Mean website orders: 3.32590799031477
# Mean mobile orders: 12.076513317191283
# Mean catalogue orders: 2.1530266343825666
# Mean discount orders: 4.343825665859564
# Website conversion: 0.535057650358367
# Mobile conversion: 0.4033056247371996
# Mean 1: 0.2188861985472155
# Mean 2: 0.19176755447941887
# Mean 3: 0.24745762711864408
# Mean 4: 0.22518159806295399
# Mean 5: 0.2324455205811138

# %%
before_people = df[df['last_order_dt'] < pd.to_datetime("2024-06-25")]
before_people_marketing = pd.DataFrame({
    'marketing_company_outcome_1': before_people['marketing_company_outcome_1'],
    'marketing_company_outcome_2': before_people['marketing_company_outcome_2'],
    'marketing_company_outcome_3': before_people['marketing_company_outcome_3'],
    'marketing_company_outcome_4': before_people['marketing_company_outcome_4'],
    'marketing_company_outcome_5': before_people['marketing_company_outcome_5']
})

website_orders = before_people['website_purchases_count_avg']
mobile_orders = before_people['mobile_purchases_count_avg']
catalogue_orders = before_people['catalogue_purchases_count_avg']
discount_orders = before_people['discount_purchases_count_avg']

print("Mean website orders:", website_orders.mean())
print("Mean mobile orders:", mobile_orders.mean())
print("Mean catalogue orders:", catalogue_orders.mean())
print("Mean discount orders:", discount_orders.mean())

website_conversion = website_orders.mean() / after_people['website_visit_count_avg'].mean()
mobile_conversion = mobile_orders.mean() / after_people['mobile_visit_count_avg'].mean()

print("Website conversion:", website_conversion)
print("Mobile conversion:", mobile_conversion)


before_people_marketing

# Для каждого столбца найдем конверсию маркетинга
for i in range(1, 6):
    print(f"Mean {i}:", before_people_marketing[f'marketing_company_outcome_{i}'].mean())
# Out:
# Mean website orders: 3.2210857592446893
# Mean mobile orders: 9.149488591660111
# Mean catalogue orders: 1.9158143194335169
# Mean discount orders: 2.9504327301337527
# Website conversion: 0.5181943045216799
# Mobile conversion: 0.305555098194814
# Mean 1: 0.21243115656963021
# Mean 2: 0.18253343823760818
# Mean 3: 0.2022029897718332
# Mean 4: 0.1982690794649882
# Mean 5: 0.2108575924468922

# %%
columns = before_people  # Список столбцов для анализа

for col in columns:
    try:
        stat, p = stats.ttest_ind(before_people[col], after_people[col], nan_policy='omit')  # Игнорирование NaN значений
        print(f'{col}: Statistics={stat:.3f}, p={p:.3f}')
        if p < 0.05:
            print(f'В столбце {col} есть статистически значимые различия.')
        else:
            print(f'В столбце {col} нет статистически значимых различий.')
    except:
        pass
# Out:
# complain_count: Statistics=0.155, p=0.877
# В столбце complain_count нет статистически значимых различий.
# discount_purchases_count_avg: Statistics=-7.583, p=0.000
# В столбце discount_purchases_count_avg есть статистически значимые различия.
# catalogue_purchases_count_avg: Statistics=-2.495, p=0.013
# В столбце catalogue_purchases_count_avg есть статистически значимые различия.
# store_purchases_count_avg: Statistics=-0.778, p=0.437
# В столбце store_purchases_count_avg нет статистически значимых различий.
# website_purchases_count_avg: Statistics=-1.020, p=0.308
# В столбце website_purchases_count_avg нет статистически значимых различий.
# website_visit_count_avg: Statistics=-6.285, p=0.000
# В столбце website_visit_count_avg есть статистически значимые различия.
# mobile_purchases_count_avg: Statistics=-6.911, p=0.000
# В столбце mobile_purchases_count_avg есть статистически значимые различия.
# mobile_visit_count_avg: Statistics=-7.267, p=0.000
# ...

# %%
after_freq = after_people['frequency']
before_freq = before_people['frequency']

print("Mean frequency after:", after_freq.mean())
print("Mean frequency before:", before_freq.mean())
# Out:
# Mean frequency after: 56.58111380145279
# Mean frequency before: 51.832415420928406

# %%
data_for_plot = df.groupby('last_order_dt').size()

print(data_for_plot)

plt.figure(figsize=(10, 6))
data_for_plot.plot(kind='bar')
plt.xlabel('Дата')
plt.ylabel('Количество пользователей')
plt.title('Количество пользователей, для которых день стал последней покупкой')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# last_order_dt
# 2024-05-
# ...

# %%
data_for_plot = df.groupby('last_order_dt')['marketing_company_outcome_4'].mean()

# Вывод средних значений конверсии для проверки
print(data_for_plot)

# Построение графика
plt.figure(figsize=(10, 6))
data_for_plot.plot(kind='bar')
plt.xlabel('Дата')
plt.ylabel('Средняя конверсия')
plt.title('Средняя конверсия пользователей, для которых день стал последней покупкой')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# last_order_dt
# 2024-05-11    0.250000
# 2024-05-12    0.160000
# 2024-05-13    0.259259
# 2024-05-14    0.133333
# 2024-05-15    0.166667
# 2024-05-16    0.160000
# 2024-05-17    0.176471
# 2024-05-18    0.176471
# 2024-05-19    0.250000
# 2024-05-20    0.206897
# 2024-05-21    0.230769
# 2024-05-22    0.107143
# 2024-05-23    0.125000
# 2024-05-24    0.222222
# 2024-05-25    0.090909
# 2024-05-26    0.148148
# 2024-05-27    0.290323
# 2024-05-28    0.208333
# 2024-05-29    0.103448
# 2024-05-30    0.238095
# 2024-05-31    0.172414
# 2024-06-01    0.285714
# 2024-06-02    0.242424
# 2024-06-03    0.321429
# 2024-06-04    0.217391
# 2024-06-05    0.151515
# 2024-06-06    0.142857
# 2024-06-07    0.218750
# 2024-06-08    0.178571
# 2024-06-09    0.205882
# 2024-06-10    0.266667
# 2024-06-11    0.178571
# 2024-06-12    0.071429
# 2024-06-13    0.208333
# 2024-06-14    0.222222
# 2024-06-15    0.181818
# 2024-06-16    0.243243
# 2024-06-17    0.238095
# 2024-06-18    0.166667
# ...

# %%
data_for_plot = df.groupby('last_order_dt')['marketing_company_outcome_5'].mean()

# Вывод средних значений конверсии для проверки
print(data_for_plot)

# Построение графика
plt.figure(figsize=(10, 6))
data_for_plot.plot(kind='bar')
plt.xlabel('Дата')
plt.ylabel('Средняя конверсия')
plt.title('Средняя конверсия пользователей, для которых день стал последней покупкой')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# last_order_dt
# 2024-05-11    0.178571
# 2024-05-12    0.120000
# 2024-05-13    0.148148
# 2024-05-14    0.166667
# 2024-05-15    0.300000
# 2024-05-16    0.080000
# 2024-05-17    0.352941
# 2024-05-18    0.117647
# 2024-05-19    0.285714
# 2024-05-20    0.137931
# 2024-05-21    0.192308
# 2024-05-22    0.142857
# 2024-05-23    0.333333
# 2024-05-24    0.333333
# 2024-05-25    0.090909
# 2024-05-26    0.222222
# 2024-05-27    0.225806
# 2024-05-28    0.250000
# 2024-05-29    0.137931
# 2024-05-30    0.190476
# 2024-05-31    0.103448
# 2024-06-01    0.285714
# 2024-06-02    0.242424
# 2024-06-03    0.357143
# 2024-06-04    0.173913
# 2024-06-05    0.121212
# 2024-06-06    0.200000
# 2024-06-07    0.062500
# 2024-06-08    0.214286
# 2024-06-09    0.205882
# 2024-06-10    0.233333
# 2024-06-11    0.321429
# 2024-06-12    0.214286
# 2024-06-13    0.166667
# 2024-06-14    0.222222
# 2024-06-15    0.303030
# 2024-06-16    0.270270
# 2024-06-17    0.190476
# 2024-06-18    0.194444
# ...

# %%
df_masters = df[df['education'] == 'masters']

data_for_plot = df_masters.groupby('last_order_dt')['discount_purchases_count_avg'].mean()

# Plotting for masters
plt.figure(figsize=(10, 6))
data_for_plot.plot(kind='bar')
plt.xlabel('Дата')
plt.ylabel('Среднее время в днях')
plt.title('Среднее время между регистрацией и посл��дней покупкой по датам последней покупки (Masters)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
